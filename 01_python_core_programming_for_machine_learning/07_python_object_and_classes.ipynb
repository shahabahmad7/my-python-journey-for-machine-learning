# %% [markdown]
# ## Classes and Objects

# %%
# a simple class object and method example 
class Robot:
    def __init__(self, name, colour):
     self.name = name
     self.colour = colour

    def introduce(self):
        print(f"{self.name} is my name and my colour is {self.colour}")

robot_1 = Robot("Shahab", "black")
robot_2 = Robot("Abbas", "yellow")
robot_1.introduce()
robot_2.introduce()
# Out:
# Shahab is my name and my colour is black
# Abbas is my name and my colour is yellow

# %%
class Car:
    max_speed = 120   # defualt speed for all vehicles

    def __init__(self, make, model, colour, speed=0):
        self.make = make
        self.model = model
        self.colour = colour
        self.speed = speed

    def accelarates(self, accelaration):
        if self.speed + accelaration <= Car.max_speed:
            self.speed += accelaration
        else:
            self.speed = Car.max_speed

    # to get current speed of the car
    def get_speed(self):
        return self.speed
    
car1 = Car("Toyota", "Altis", "white")
car2 = Car("Merecedes", "G-wagon", "black")
car1.accelarates(130)
car2.accelarates(60)

print(f"{car1.make} {car1.model} is currently at {car1.get_speed()} km/h.")
print(f"{car2.make} {car2.model} is currently at {car2.get_speed()} km/h.")
# Out:
# Toyota Altis is currently at 120 km/h.
# Merecedes G-wagon is currently at 60 km/h.
